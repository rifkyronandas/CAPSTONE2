# %% [markdown]
# ---
# # **AWS SaaS Sales Analysis**
# # By: Rifky Ronanda
# ---

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
# ### **A. Company Overview**

# %% [markdown]
# Amazon Web Services / AWS telah berdiri didunia sebagai platform yang paling komprehensif dan paling banyak digunakan didunia, serta memiliki lebih dari 200 layanan berfitur lengkap yang dapat diakses dari pusat data di seluruh dunia. Telah dipercaya oleh jutaan pengguna termasuk beberapa startups yang sedang berkembang, perusahaan terkenal didunia, dan lembaga pemerintah terkemuka, selain itu juga AWS memberikan pengguna serta komunitasnya untuk dapat mengurangi biaya operational, meningkatkan aglity serta mempercepat inovasi dengan adanya AWS tersebut.
#
# Layanan dalam AWS mencakup beberapa spektrum penting diantaranya komputasi, basis data , penyimpanan/storage, aplikasi berbasis web maupun mobile,serverless,machine learning dan software as a service (Saas), berbagai fungsi andalan ini juga dapat memungkinkan pengguna menyesuaikan kebutuhan bisnis mereka dan menjadikan AWS sebagai landasan transformasi digital
#
# **Apasih SaaS itu?**
#
# Saas merupakan sebuah perangkat lunak berbasis cloud, memberikan akses langsung ke pengguna melalui browser internet. Dalam model ini, vendor SaaS menghosting layanan dan aplikasi, memberikan pengguna akses sesuai permintaan, salah satu benefit atau keuntungannya ialah meminimalisi resoka yang terjadi pada pengelolaan infrastruktur karena fokusnya hanya beralih ke penggunaan perangkat lunak, Selain itu, SaaS biasanya mengadopsi model subscribtion/ berlangganan serta pay-as-you-use/ bayar sesuai penggunaan yang membedakan pemabayaran menyeluruh didepan seperti aplikasi-aplikasi kompetitor, Contoh klasiknya adalah email berbasis web, di mana pengguna dapat mengirim dan menerima pesan dengan lancar tanpa harus bergulat dengan tanggung jawab pemeliharaan atau kerumitan infrastruktur.
#
#
# **AWS and Software-as-a-Service (SaaS):**
#
# Dalam ekosistem AWS, Software-as-a-Service (SaaS) muncul sebagai model bisnis yang penting. Pendekatan inovatif ini memfasilitasi komunitas dalam memberikan solusi mereka dengan berbagai kemudahan yang ada AWS juga berkolaborasi dengan perusahaan untuk merancang model SaaS yang memprioritaskan Aglity/ ketangkasan dan efisiensi operasional, mendorong strategi bisnis yang mendorong pertumbuhan, memperluas jangkauan, dan memacu inovasi.
#
# Dengan mengintegrasikan rangkaian layanan AWS secara lancar, termasuk model SaaS yang ekstensif, komunitas dapat berinovasi lebih cepat, serta memberikan proposisi nilai yang berbeda kepada pelanggan mereka.

# %% [markdown]
# ### **B. Define Business Problem**

# %% [markdown]
# Analisis Faktor-Faktor yang Mempengaruhi `Profit Negatif` Dalam AWS Software Sales pada rentang periode (January 2020 - December 2023)
#
# Tujuan analisis ini adalah untuk mengidentifikasi dan mengeksplorasi faktor-faktor utama yang berkontribusi terhadap keuntungan negatif dalam penjualan perangkat lunak AWS selama periode Januari 2020 hingga Desember 2023. Di antara total 9994 transaksi yang dianalisis, `8058` transaksi menghasilkan `Profit Positif dengan total USD 442,528.31`, sedangkan `1936` transaksis yang terekam tercatat `profit 0 atau profit negatif dengan total sekitar -USD 156,131.29`.

# %%
pos = aws['Profit'] > 0
neg = aws['Profit'] < 0

display(aws[pos].head(),f'Transaksi dengan profit positif sebanyak {len(aws[pos])} transaksi dengan jumlah transaksi sebesar USD 442528.31')
display(aws[neg].head(),f'Transaksi dengan profit negatif sebanyak {len(aws[neg])} transaksi dengan jumlah transaksi sebesar -USD 156131.29')
# Out:
#    Row ID          Order ID  Order Date  Date Key    Contact Name
# 0       1  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell  \
# 1       2  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 2       3  AMER-2022-138688   6/13/2022  20220613  Deirdre Bailey
# 4       5  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
# 5       6  AMER-2020-115812    6/9/2020  20200609   Thomas Hodges
#
#          Country           City Region Subregion           Customer
# 0        Ireland         Dublin   EMEA      UKIR            Chevron  \
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 5  United States  New York City   AMER     NAMER        BNP Paribas
#
#    Customer ID Industry    Segment                 Product     License
# 0         1017   Energy        SMB         Marketing Suite  16GRM07R1K  \
# ...

# %%
labels = [f'Profit Positif \n {len(aws[pos])} Transaksi \n Jumlah Profit USD {round(aws[aws["Profit"] > 0]["Profit"].sum(),2)}',f'Profit Negatif \n {len(aws[neg])} Transaksi \n Jumlah Profit -USD 156131.29']
sizes = [len(aws[pos]), len(aws[neg])]
colors = ['#2f4067', '#f29700']

fig, ax = plt.subplots(figsize=(7,7), facecolor='#0f2850')
text_props = {'color': '#f5f6fa', 'weight': 'bold'}
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, textprops=text_props)
plt.axis('equal')  # Membuat lingkaran menjadi lingkaran sempurna
plt.title('Distribusi Transaksi berdasarkan Profit', color='#f5f6fa', weight= 'bold')
plt.show()

# %% [markdown]
# `1. Sales Performance Analysis:`
# Tujuan utamanya adalah untuk menyelidiki secara menyeluruh kinerja penjualan perusahaan. Mengidentifikasi faktor-faktor yang mempengaruhi penjualan dan profitabilitas, khususnya laba negatif, memerlukan analisis dampak diskon terhadap penjualan, kinerja penjualan produk tertentu, dan mengamati tren penjualan dari waktu ke waktu.
#
# `2. Customer Segment Analysis:`
# Melakukan analisis komprehensif terhadap segmen pelanggan berdasarkan perilaku pembelian mereka (Analisis RFM) adalah hal yang terpenting. Menjelajahi metrik seperti frekuensi pembelian, produk pilihan, dan distribusi geografis pelanggan memberikan wawasan yang berharga.
#
# `3. Geographic Marketing Analysis:`
# Identifying the performance of sales based on regions or subregions is crucial. Understanding customer distribution across different areas facilitates informed marketing strategies.
#
# ---
#
# `Problem Statement`
#
# **Analyzing factors contributing to negative profitability in AWS SaaS product sales, examining the influence of marketing strategies (discounts), market segmentation, and customer distribution in each region.**

# %% [markdown]
# ### **C. Analysis Goals**

# %% [markdown]
# `1. Uncover Sales Optimization Strategies:` Identify and implement strategies to optimize sales performance, specifically targeting factors influencing negative profitability. This includes refining the impact of discount strategies, enhancing the sales performance of specific products, and aligning marketing efforts with observed sales trends.
#
# `2. Enhance Customer Engagement and Satisfaction:` Improve customer engagement and satisfaction by tailoring strategies based on a thorough understanding of customer segments. Utilize insights from purchase frequency, preferred products, and geographical distribution to tailor offerings that resonate with different customer groups.
#
# `3. Refine Geographic Marketing Tactics:` Refine marketing tactics based on a detailed geographic analysis. Identify top-performing regions or subregions and strategize marketing efforts to align with customer distribution, ensuring a targeted and effective approach in each area.

# %% [markdown]
# ### **D. Dataset General Information**

# %% [markdown]
# #### **Import libraries and Load Dataset**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Import Dataset

aws = pd.read_csv('SaaS-Sales.csv')
aws.head()
# Out:
#    Row ID          Order ID  Order Date  Date Key    Contact Name
# 0       1  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell  \
# 1       2  EMEA-2022-152156   11/9/2022  20221109     Nathan Bell
# 2       3  AMER-2022-138688   6/13/2022  20220613  Deirdre Bailey
# 3       4  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
# 4       5  EMEA-2021-108966  10/11/2021  20211011      Zoe Hodges
#
#          Country           City Region Subregion           Customer
# 0        Ireland         Dublin   EMEA      UKIR            Chevron  \
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License
# 0         1017   Energy        SMB         Marketing Suite  16GRM07R1K  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'aws' is your DataFrame

# Get unique products
unique_products = aws['Product'].unique()

# Calculate the number of rows needed based on the number of unique products
num_rows = (len(unique_products) + 1) // 2  # Use // for integer division

# Create subplots with 2 columns
fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, 6 * num_rows))

# Iterate through unique products and create boxplot for each
for idx, product in enumerate(unique_products):
    row_idx = idx // 2  # Calculate the row index
    col_idx = idx % 2   # Calculate the column index

    temp = aws[aws['Product'] == product]
    
    # Create boxplot
    sns.boxplot(x=temp['Discount'], ax=axes[row_idx, col_idx])
    
    # Set title for each subplot
    axes[row_idx, col_idx].set_title(f'Boxplot Discount - {product}')
    axes[row_idx, col_idx].set_xlabel('Discount')
    axes[row_idx, col_idx].set_ylabel('')

# Remove empty subplots if the number of unique products is odd
if len(unique_products) % 2 != 0:
    fig.delaxes(axes[num_rows-1, 1])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
aws['Product'].unique()
# Out:
# array(['Marketing Suite', 'FinanceHub', 'ContactMatcher',
#        'Marketing Suite - Gold', 'SaaS Connector Pack', 'ChatBot Plugin',
#        'Site Analytics', 'OneView', 'Support', 'Data Smasher',
#        'SaaS Connector Pack - Gold', 'Storage', 'Big Ol Database',
#        'Alchemy'], dtype=object)

# %%
aws[((aws['Product']=='OneView') & (aws['Discount'] >= 0.8 )) ].head(5)
# Out:
#      Row ID         Order ID  Order Date  Date Key      Contact Name
# 14       15  APJ-2021-118983  11/22/2021  20211122    Emily Morrison  \
# 169     170  APJ-2020-139892    9/8/2020  20200908  Melanie Davidson
# 174     175  APJ-2020-100853   9/14/2020  20200914   Gabrielle Ogden
# 176     177  APJ-2023-152366   4/22/2023  20230422    Justin Randall
# 203     204  APJ-2023-116701  12/18/2023  20231218        Diana Bell
#
#        Country     City Region Subregion           Customer  Customer ID
# 14       Japan  Saitama    APJ      JAPN             Pfizer         1074  \
# 169      Japan    Osaka    APJ      JAPN       Nissan Motor         1098
# 174  Australia   Sydney    APJ       ANZ  Royal Dutch Shell         1031
# 176      Japan    Tokyo    APJ      JAPN        Wells Fargo         1099
# 203      Japan    Aichi    APJ      JAPN      Sprint Nextel         1081
#
#            Industry     Segment  Product     License    Sales  Quantity
# ...

# %%
aws[((aws['Product']=='SaaS Connector Pack') & (aws['Discount'] >= 0.6 )) ].head(5)
# Out:
#      Row ID         Order ID  Order Date  Date Key    Contact Name    Country
# 36       37  APJ-2022-117590   12/9/2022  20221209     Chloe Short      Japan  \
# 76       77  APJ-2023-118038  12/10/2023  20231210      Maria Dyer      Japan
# 78       79  APJ-2020-147606  11/26/2020  20201126        Anne Lee      Japan
# 238     239  APJ-2022-157749    6/5/2022  20220605  Trevor Langdon  Australia
# 239     240  APJ-2022-157749    6/5/2022  20220605  Trevor Langdon  Australia
#
#        City Region Subregion          Customer  Customer ID
# 36    Aichi    APJ      JAPN  Procter & Gamble         1077  \
# 76    Tokyo    APJ      JAPN      Nissan Motor         1098
# 78    Tokyo    APJ      JAPN            Oracle         1072
# 238  Sydney    APJ       ANZ            Target         1085
# 239  Sydney    APJ       ANZ            Target         1085
#
#               Industry    Segment              Product     License    Sales
# ...

# %%
# Komposisi Data

x,z = aws.shape
print(f'{x} baris , {z} kolom')
# Out:
# 9994 baris , 19 kolom

# %% [markdown]
# #### **Rows Explanation**

# %% [markdown]
# This dataset comprises 9994 rows, each representing the purchase data for individual software licenses. It includes information such as Order ID, Order Date, Date Key, Contact Name, Country, City, Region, Subregion, Customer, Customer ID, Industry, Segment, Product, License, Sales, Quantity, Discount, and Profit.

# %% [markdown]
# #### **Columns Explanation**

# %% [markdown]
# - `Row ID:` A unique identifier for each transaction in the dataset. This column serves as a unique identification number for each transaction row, used for reference and specific identification of each entry in the dataset.
#
# - `Order ID:` A unique identifier for each order with the format Region-Year-Unique ID. Order ID is used to track and identify each order. Its format includes information about the region (Region), the year the order was placed (Year), and a unique ID for each order.
#
# - `Order Date:` The date when the order was placed. Presents information about when the order was made. Useful for analyzing time trends and tracking when sales activity increases or decreases.
#
# - `Date Key:` Numeric representation of the Order Date in the YYYYMMDD format. Provides a numeric representation of the order date, which can be used for further analysis with a numerical approach.
#
# - `Contact Name:` The name of the person who placed the order. This column lists the name of the individual responsible for placing the order, providing insight into the people involved in the sales process.
#
# - `Country:` The country where the order was placed. Presents information about the geographical location from which the order originates. Useful for analyzing sales based on country.
#
# - `City:` The city where the order was placed. Gives further information about the specific location within the country where the order originated.
#
# - `Region:` The geographical region of the order (EMEA, AMER, APJ). Indicates the global region where the order was placed, aiding in geographical mapping and sales analysis.
#
# - `Subregion:` The sub-geographical region where the order was placed. Provides a more detailed level of information about the geographical location of the order, aiding in deeper regional analysis.
#
# - `Customer:` The name of the company that placed the order. Presents information about the customer or company placing the order, aiding in tracking and analyzing customer activity.
#
# - `Customer ID:` A unique identifier for each customer. This column serves as a unique identification number for each customer, allowing the tracking of transactions from a specific customer.
#
# - `Industry:` The industry the customer belongs to (Energy, Finance, Tech, Healthcare, etc.). Provides insight into the customer's industry sector, allowing analysis of sales trends based on industry.
#
# - `Segment:` The customer segment (SMB, Strategic, Enterprise, etc.). Indicates the customer category based on size and business strategy, useful for understanding customer profiles.
#
# - `Product:` The product that was ordered. Presents information about the product purchased by the customer, enabling analysis of product popularity and contribution to overall sales.
#
# - `License:` The unique license key for the product. This column contains a unique license key associated with each ordered product.
#
# - `Sales:` The total sales amount for the transaction . Indicates the total sales value of a specific order, providing information about the financial performance of that transaction.
#
# - `Quantity:` The total number of items in the transaction. This column lists the total quantity of items or products purchased in a single transaction.
#
# - `Discount:` The discount applied to the transaction. Presents information about the amount of discount applied to a specific transaction.
#
# - `Profit:` The profit from the transaction (in USD). Indicates the profit value generated from the transaction, allowing evaluation of the profitability of products or services.

# %%
# Data Type
aws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   object
#  2   Order Date    9994 non-null   object
#  3   Date Key      9994 non-null   int64
#  4   Contact Name  9994 non-null   object
#  5   Country       9994 non-null   object
#  6   City          9994 non-null   object
#  7   Region        9994 non-null   object
#  8   Subregion     9994 non-null   object
#  9   Customer      9994 non-null   object
#  10  Customer ID   9994 non-null   int64
#  11  Industry      9994 non-null   object
#  12  Segment       9994 non-null   object
#  13  Product       9994 non-null   object
#  14  License       9994 non-null   object
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
#  17  Discount      9994 non-null   float64
# ...

# %%
# Cek unique values tiap kolom
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None) 

def unique_data(aws):
    
    data_unique = pd.DataFrame()
    data_unique['Columns'] = aws.columns
    data_unique['Unique Count'] = [aws[col].nunique() for col in (aws.columns)]
    data_unique['Unique'] = [aws[col].unique() for col in (aws.columns)]
    
    return data_unique

unique_data(aws)
# Out:
#          Columns  Unique Count
# 0         Row ID          9994  \
# 1       Order ID          5009
# 2     Order Date          1237
# 3       Date Key          1237
# 4   Contact Name           793
# 5        Country            48
# 6           City           262
# 7         Region             3
# 8      Subregion            12
# 9       Customer            99
# 10   Customer ID            99
# 11      Industry            10
# 12       Segment             3
# 13       Product            14
# 14       License          9994
# 15         Sales          5825
# 16      Quantity            14
# 17      Discount            12
# 18        Profit          7287
#
# ...

# %% [markdown]
# ## **Data Cleaning and Manipulating**
# ---

# %% [markdown]
# ### **1. Duplicates Handling**

# %%
aws[aws.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Date Key, Contact Name, Country, City, Region, Subregion, Customer, Customer ID, Industry, Segment, Product, License, Sales, Quantity, Discount, Profit]
# Index: []

# %%
duplicate_rows = aws[aws.duplicated(subset=aws.columns)]


print("Jumlah duplikat antar baris dalam dataset: ", duplicate_rows.shape[0])
print("Baris duplikat:")
print(duplicate_rows)
# Out:
# Jumlah duplikat antar baris dalam dataset:  0
# Baris duplikat:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Date Key, Contact Name, Country, City, Region, Subregion, Customer, Customer ID, Industry, Segment, Product, License, Sales, Quantity, Discount, Profit]
# Index: []

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Region', data=duplicate_rows, hue='Region')
plt.title('Distribusi Duplikat Antar Baris Berdasarkan Region')
plt.show()

# %% [markdown]
# ### **2. Missing Value Handling**

# %%
aws.isnull().sum()
# Out:
# Row ID          0
# Order ID        0
# Order Date      0
# Date Key        0
# Contact Name    0
# Country         0
# City            0
# Region          0
# Subregion       0
# Customer        0
# Customer ID     0
# Industry        0
# Segment         0
# Product         0
# License         0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
print('Missing values status:', aws.isnull().values.any())
missing_values = pd.DataFrame(aws.isnull().sum(), columns=['Total Null Values'])
missing_values['Percentage'] = (missing_values['Total Null Values'] / aws.shape[0]) * 100
missing_values.sort_values(by='Percentage', ascending=False).reset_index()
# Out:
# Missing values status: False
#            index  Total Null Values  Percentage
# 0         Row ID                  0         0.0
# 1    Customer ID                  0         0.0
# 2       Discount                  0         0.0
# 3       Quantity                  0         0.0
# 4          Sales                  0         0.0
# 5        License                  0         0.0
# 6        Product                  0         0.0
# 7        Segment                  0         0.0
# 8       Industry                  0         0.0
# 9       Customer                  0         0.0
# 10      Order ID                  0         0.0
# 11     Subregion                  0         0.0
# 12        Region                  0         0.0
# 13          City                  0         0.0
# 14       Country                  0         0.0
# 15  Contact Name                  0         0.0
# 16      Date Key                  0         0.0
# 17    Order Date                  0         0.0
# ...

# %%
plt.figure(figsize = (12, 5))
sns.heatmap(data = aws.isna(), vmin = 0, vmax = 1)
plt.show()

# %%
# Memeriksa missing value dalam DataFrame (xo adalah contoh nama DataFrame)
missing_values = aws.isnull()

# Membuat heatmap untuk visualisasi
plt.figure(figsize=(10, 6))
plt.imshow(missing_values, cmap='viridis', aspect='auto', interpolation='none')
plt.title('Visualisasi Missing Value pada DataFrame aws')
plt.colorbar()
plt.show()

# %%
missing_values = aws.isnull().sum()

# Visualisasi missing values
plt.figure(figsize=(12, 6))
sns.heatmap(aws.isnull(), cmap='viridis', cbar=False, yticklabels=False)
plt.title('Missing Values in the Dataset')
plt.show()

# Menampilkan jumlah missing values di setiap kolom
print("Jumlah Missing Values per Kolom:")
print(missing_values)
# Out:
# Jumlah Missing Values per Kolom:
# Row ID          0
# Order ID        0
# Order Date      0
# Date Key        0
# Contact Name    0
# Country         0
# City            0
# Region          0
# Subregion       0
# Customer        0
# Customer ID     0
# Industry        0
# Segment         0
# Product         0
# License         0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### **3. Anomalies Handling**

# %% [markdown]
# #### **3.1. Anomalies on Order ID**

# %%
#Mengecek jumlah nilai unique pada kolom order ID

aws['Order ID'].nunique()
# Out:
# 5009

# %%
#mengecek 5 data pertama nilai unique dalam kolom license yang dikelompokkan berdasarkan kolom order ID

aws.groupby('Order ID')['License'].unique().reset_index().head()
# Out:
#            Order ID                                           License
# 0  AMER-2020-100090                          [4BEAB9UXKH, AVBMH39MTD]
# 1  AMER-2020-100279                                      [NI5MITNJ98]
# 2  AMER-2020-100363                          [0O2MCUTMFW, 7ZEJI08M1P]
# 3  AMER-2020-100762  [9WNGMUMGIU, QLK9TG5206, V5SQA48WYZ, 5F2LX40BDP]
# 4  AMER-2020-100860                                      [T3NURF3EZL]

# %%
# menghitung seluruh jumlah data yang terduplikat pada kolom license

aws['License'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# **1. Order ID Patterns:**
#
# - The Order IDs seem to follow a pattern: "AMER-2020-" followed by a numerical sequence. This suggests a potential ordering system based on each regions (AMER for the Americas) and the year 2020.
#
# **2. Diversity in License Key Formats:**
#
# - The format of the license keys appears alphanumeric, possibly generated randomly or according to a specific algorithm. Some keys are longer (10 characters), while others are shorter (9 characters). So there is no problems between this License Key Formating.
#
# **3. Unique Keys per Order:**
#
# - Each order seems to have its unique set of license keys, indicating individual purchases or allocations so there must be NO duplicates in each License.

# %% [markdown]
# #### **3.2. Anomalies on Order Date**

# %%
aws['Order Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9994 entries, 0 to 9993
# Series name: Order Date
# Non-Null Count  Dtype
# --------------  -----
# 9994 non-null   object
# dtypes: object(1)
# memory usage: 78.2+ KB

# %% [markdown]
# - Type data pada kolom `Order Date` masih object, maka akan diubah menjadi datetime agar mempermudah proses analisa trend waktu

# %%
aws['Order Date'] = pd.to_datetime(aws['Order Date'])

# %%
aws['Order Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9994 entries, 0 to 9993
# Series name: Order Date
# Non-Null Count  Dtype
# --------------  -----
# 9994 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 78.2 KB

# %% [markdown]
# #### **3.3. Anomalies on Country**

# %% [markdown]
# ##### 1

# %%
aws.groupby('Region')['Country'].unique().reset_index()
# Out:
#   Region
# 0   AMER  \
# 1    APJ
# 2   EMEA
#
#                                                                                                                                                                                                                                                                                                         Country
# 0                                                                                                                                                                                                                               [United States, Canada, Costa Rica, Brazil, Chile, Colombia, Mexico, Argentina]
# 1                                                                                                                                                                                                         [Japan, Australia, Philippines, India, Singapore, New Zealand, South Korea, China, Indonesia, Taiwan]
# ...

# %% [markdown]
# #####

# %%
aws.groupby('Subregion')['Country'].unique().reset_index()
# Out:
#    Subregion
# 0        ANZ  \
# 1       APAC
# 2         EU
# 3    EU-EAST
# 4    EU-WEST
# 5        IND
# 6       JAPN
# 7      LATAM
# 8        MEA
# 9      NAMER
# 10       NOR
# 11      UKIR
#
#                                                                                                                        Country
# 0                                                                                                     [Australia, New Zealand]
# 1                                                              [Philippines, Singapore, South Korea, China, Indonesia, Taiwan]
# 2                                                                                                                      [Italy]
# 3                                                                            [Russia, Czech Republic, Israel, Ukraine, Greece]
# 4   [Germany, France, Luxembourg, Spain, Portugal, Belgium, Netherlands, Poland, Austria, Denmark, Croatia, Slovenia, Iceland]
# ...

# %%
aws.groupby('Country')['City'].unique().reset_index()
# Out:
#                  Country
# 0              Argentina  \
# 1              Australia
# 2                Austria
# 3                Belgium
# 4                 Brazil
# 5                 Canada
# 6                  Chile
# 7                  China
# 8               Colombia
# 9             Costa Rica
# 10               Croatia
# 11        Czech Republic
# 12               Denmark
# 13                 Egypt
# 14               Finland
# 15                France
# 16               Germany
# 17                Greece
# 18               Iceland
# 19                 India
# 20             Indonesia
# 21               Ireland
# 22                Israel
# 23                 Italy
# 24                 Japan
# 25            Luxembourg
# 26                Mexico
# 27           Netherlands
# 28           New Zealand
# 29                Norway
# 30           Philippines
# 31                Poland
# 32              Portugal
# 33                 Qatar
# 34                Russia
# ...

# %% [markdown]
# ### **4. Outliers Handling**

# %% [markdown]
# ### **5. Dropping Unnecessary Columns**

# %% [markdown]
# ### **6. Adding New Necessary Columns**

# %% [markdown]
# #### **6.1. Adding Year and Month Columns**

# %%
aws.insert(3, 'Year', aws['Order Date'].dt.year)
aws.insert(4, 'Month', aws['Order Date'].dt.month)

# %% [markdown]
# ## **Data Analysis and Insight**
# ---

# %% [markdown]
# ### **Problems**

# %%
labels = [f'Profit Positif \n {len(aws[pos])} Transaksi \n Jumlah Profit USD {round(aws[aws["Profit"] > 0]["Profit"].sum(),2)}',f'Profit Negatif \n {len(aws[neg])} Transaksi \n Jumlah Profit -USD 156131.29']
sizes = [len(aws[pos]), len(aws[neg])]
colors = ['#2f4067', '#f29700']

fig, ax = plt.subplots(figsize=(7,7), facecolor='#0f2850')
text_props = {'color': '#f5f6fa', 'weight': 'bold'}
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, textprops=text_props)
plt.axis('equal')
plt.title('Distribusi Transaksi berdasarkan Profit', color='#f5f6fa', weight= 'bold')
plt.show()

# %% [markdown]
# 1. Analysis of Factors Influencing `Negative Profits` in AWS Software Sales (January 2020 - December 2023)
#
# The objective of this analysis is to identify and explore the key factors contributing to negative profits in AWS software sales during the period from January 2020 to December 2023. Among a total of 9994 transactions analyzed, `8058` transactions yielded `positive profits totaling USD 442,528.31`, while `1936` transactions recorded either `zero profits or negative profits amounting to -USD 156,131.29`.
#
# 2. Menganalisa Strategi untuk meningkatkan `Sales dan Profit`

# %%
aws.head()
# Out:
#    Row ID          Order ID Order Date  Year  Month  Date Key    Contact Name
# 0       1  EMEA-2022-152156 2022-11-09  2022     11  20221109     Nathan Bell  \
# 1       2  EMEA-2022-152156 2022-11-09  2022     11  20221109     Nathan Bell
# 2       3  AMER-2022-138688 2022-06-13  2022      6  20220613  Deirdre Bailey
# 3       4  EMEA-2021-108966 2021-10-11  2021     10  20211011      Zoe Hodges
# 4       5  EMEA-2021-108966 2021-10-11  2021     10  20211011      Zoe Hodges
#
#          Country           City Region Subregion           Customer
# 0        Ireland         Dublin   EMEA      UKIR            Chevron  \
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License
# ...

# %% [markdown]
# ### **1. Sales Performance Analysis**

# %% [markdown]
# ##### **The product that contributes the highest Quantity sold and Profit**

# %%
prod_most_sales = aws.groupby('Product').agg({'Quantity' : 'sum'}).reset_index().sort_values(by='Quantity', ascending=False)
prod_most_sales
# Out:
#                        Product  Quantity
# 3               ContactMatcher      7215
# 13                     Support      5825
# 5                   FinanceHub      3756
# 9          SaaS Connector Pack      3563
# 11              Site Analytics      3289
# 7       Marketing Suite - Gold      3158
# 2               ChatBot Plugin      3000
# 4                 Data Smasher      2976
# 8                      OneView      1729
# 12                     Storage       914
# 10  SaaS Connector Pack - Gold       906
# 6              Marketing Suite       868
# 1              Big Ol Database       440
# 0                      Alchemy       234

# %% [markdown]
# `Insight :`
#
# - Produk favorite dengan kuantitas terjual paling banyak yaitu `Contact Matcher` dengan kuantitas pernjualan `7215`, `Support` dengan kuantitas penjualan `5825`, dan `FinanceHub` dengan kuantitas penjualan `3756`
# - Produk yang paling tidak favorite terjual paling sedikit yaitu `Alchemy` dengan kuantitas penjualan `234`, `Big Ol Database` dengan kuanttias penjualan `440`, dan `Marketing Suite` dengan kuantitas penjualan `868`

# %%
prod_most_prof = aws.groupby('Product').agg({'Profit': 'sum'}).reset_index().sort_values(by='Profit', ascending=False)
prod_most_prof
# Out:
#                        Product      Profit
# 0                      Alchemy  55617.8249
# 11              Site Analytics  44515.7306
# 4                 Data Smasher  41936.6357
# 13                     Support  32864.4698
# 5                   FinanceHub  32136.4203
# 7       Marketing Suite - Gold  21278.8264
# 8                      OneView  18138.0054
# 9          SaaS Connector Pack  13059.1436
# 3               ContactMatcher  12496.2822
# 10  SaaS Connector Pack - Gold   6964.1767
# 2               ChatBot Plugin   6527.7870
# 1              Big Ol Database   3384.7569
# 12                     Storage    949.5182
# 6              Marketing Suite  -3472.5560

# %%
aws.head()
# Out:
#    Row ID          Order ID Order Date  Year  Month  Date Key    Contact Name
# 0       1  EMEA-2022-152156 2022-11-09  2022     11  20221109     Nathan Bell  \
# 1       2  EMEA-2022-152156 2022-11-09  2022     11  20221109     Nathan Bell
# 2       3  AMER-2022-138688 2022-06-13  2022      6  20220613  Deirdre Bailey
# 3       4  EMEA-2021-108966 2021-10-11  2021     10  20211011      Zoe Hodges
# 4       5  EMEA-2021-108966 2021-10-11  2021     10  20211011      Zoe Hodges
#
#          Country           City Region Subregion           Customer
# 0        Ireland         Dublin   EMEA      UKIR            Chevron  \
# 1        Ireland         Dublin   EMEA      UKIR            Chevron
# 2  United States  New York City   AMER     NAMER        Phillips 66
# 3        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
# 4        Germany      Stuttgart   EMEA   EU-WEST  Royal Dutch Shell
#
#    Customer ID Industry    Segment                 Product     License
# ...

# %% [markdown]
# ### **2. Customer Segment Analysis**

# %% [markdown]
# #### **2.1. Business Segment**

# %%
segment_counts = aws['Segment'].value_counts().reset_index()
segment_counts.columns = ['Segment', 'Count']
segment_counts
# Out:
#       Segment  Count
# 0         SMB   5191
# 1   Strategic   3020
# 2  Enterprise   1783

# %%
plt.figure(figsize=(8, 8))
plt.pie(segment_counts['Count'], labels=segment_counts['Segment'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'lightcoral'])
plt.title('Distribution of Segments')
plt.show()

# %%
pivot_segment_product = aws.pivot_table(index='Segment', columns='Product', aggfunc='size', fill_value=0)
pivot_segment_product
# Out:
# Product     Alchemy  Big Ol Database  ChatBot Plugin  ContactMatcher
# Segment
# Enterprise       13               23             150             324  \
# SMB              35               57             428             939
# Strategic        20               35             218             579
#
# Product     Data Smasher  FinanceHub  Marketing Suite  Marketing Suite - Gold
# Segment
# Enterprise           140         173               33                     136  \
# SMB                  408         518              131                     450
# Strategic            227         290               64                     260
#
# Product     OneView  SaaS Connector Pack  SaaS Connector Pack - Gold
# Segment
# Enterprise       67                  175                          41  \
# SMB             244                  494                         129
# Strategic       155                  288                          84
#
# Product     Site Analytics  Storage  Support
# Segment
# ...

# %%
x = aws.groupby('Segment').agg({'Order ID': 'count','Quantity': 'sum','Profit': 'sum'}).reset_index().sort_values(by='Profit', ascending=False)
x
# Out:
#       Segment  Order ID  Quantity       Profit
# 1         SMB      5191     19521  134119.2092
# 2   Strategic      3020     11608   91979.1340
# 0  Enterprise      1783      6744   60298.6785

# %% [markdown]
# #### **2.2. Profit by Industry**

# %%
prof_by_ind = aws.groupby(['Industry'])[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
prof_by_ind
# Out:
#                          Sales      Profit
# Industry
# Finance            474150.4844  50348.9696
# Energy             304644.1409  45282.3137
# Manufacturing      295192.3812  38413.1064
# Healthcare         273183.2882  31969.0932
# Tech               263169.0277  24615.0436
# Consumer Products  224044.1422  37018.0077
# Retail             223072.0720  30207.8208
# Communications     120962.2365  13976.3410
# Transportation      90191.3276   7402.6967
# Misc                28591.7596   7163.6290

# %%
pivot_industry_product = aws.pivot_table(index='Segment', columns='Product', aggfunc='size', fill_value=0)
pivot_industry_product
# Out:
# Product     Alchemy  Big Ol Database  ChatBot Plugin  ContactMatcher
# Segment
# Enterprise       13               23             150             324  \
# SMB              35               57             428             939
# Strategic        20               35             218             579
#
# Product     Data Smasher  FinanceHub  Marketing Suite  Marketing Suite - Gold
# Segment
# Enterprise           140         173               33                     136  \
# SMB                  408         518              131                     450
# Strategic            227         290               64                     260
#
# Product     OneView  SaaS Connector Pack  SaaS Connector Pack - Gold
# Segment
# Enterprise       67                  175                          41  \
# SMB             244                  494                         129
# Strategic       155                  288                          84
#
# Product     Site Analytics  Storage  Support
# Segment
# ...

# %% [markdown]
# ### **3. Trendline**

# %% [markdown]
# #### **3.1. Trendline Sales, Profit, dan Order  ID by Year**

# %%
trend_by_year = aws.groupby(['Year']).agg({'Sales': 'sum'}).reset_index().sort_values(by=['Year'])
trend_by_year
# Out:
#    Year        Sales
# 0  2020  484247.4981
# 1  2021  470532.5090
# 2  2022  608473.8300
# 3  2023  733947.0232

# %% [markdown]
# #### **3.2. Trendline Product**

# %% [markdown]
# ### **4. Geographical Marketing Analysis**

# %% [markdown]
# #### **3.1. REGION**

# %%
TransaksiReg = aws.groupby('Region')['Order ID'].count().sort_values(ascending=False)
display(TransaksiReg)
# Out:
# Region
# EMEA    4219
# AMER    3665
# APJ     2110
# Name: Order ID, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=TransaksiReg.index, y=TransaksiReg.values, hue=TransaksiReg.index, palette='muted' )
plt.title('Jumlah Transaksi berdasarkan Region\n', fontsize=16, fontweight='bold')
plt.xlabel('Region', fontsize=12, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=11, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
Region = aws.groupby('Region')['Profit'].sum().sort_values(ascending=False)
Region
# Out:
# Region
# EMEA    147456.0450
# AMER    127426.9898
# APJ      11513.9869
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=Region.index, y=Region.values, hue=Region.index, palette='muted')
plt.title('Total Profit berdasarkan Region', fontsize=14, fontweight='bold')
plt.xlabel('Month', fontsize=11, fontweight='bold')
plt.ylabel('Total Profit', fontsize=11, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **3.3. COUNTRY**

# %%
TransaksiCountry = aws.groupby('Country')['Order ID'].count().sort_values(ascending=False).head(10)
display(TransaksiCountry)

plt.figure(figsize=(14,6))
ax= sns.barplot(x=TransaksiCountry.index, y=TransaksiCountry.values, hue=TransaksiCountry.index, palette='muted' )
plt.title('Jumlah Transaksi berdasarkan Country', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=11, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=11, fontweight='bold')

max = TransaksiCountry.max()
min = TransaksiCountry.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = TransaksiCountry.index
values = TransaksiCountry.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# Country
# United States     2001
# United Kingdom    1141
# Japan              985
# France             587
# Canada             506
# Australia          492
# Mexico             469
# Germany            383
# Brazil             255
# Sweden             249
# Name: Order ID, dtype: int64

# %%
Top10Country = aws.groupby('Country')['Profit'].sum().sort_values(ascending=False).head(10)
display(Top10Country)

plt.figure(figsize=(14,6))
ax=sns.barplot(x=Top10Country.index, y=Top10Country.values,  hue=Top10Country.index, palette='muted')
plt.title('Total Profit berdasarkan Country', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=11, fontweight='bold')
plt.ylabel('Total Profit', fontsize=11, fontweight='bold')
max = Top10Country.max()
min = Top10Country.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = Top10Country.index
values = Top10Country.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Country
# United States     76381.3871
# United Kingdom    74989.0891
# Canada            33402.6517
# Brazil            24463.1876
# Spain             18597.9504
# India             18382.9363
# Finland           16250.0433
# Luxembourg        10823.1874
# Ireland           10249.1561
# Philippines        9977.3748
# Name: Profit, dtype: float64

# %% [markdown]
# #### **3.4. CITY**

# %%
TransaksiCity = aws.groupby('City')['Order ID'].count().sort_values(ascending=False).head(10)
display(TransaksiCity)

plt.figure(figsize=(14,6))
ax = sns.barplot(x=TransaksiCity.index, y=TransaksiCity.values, hue=TransaksiCity.index, palette='muted')
plt.title('Jumlah Transaksi berdasarkan City\n', fontsize=14, fontweight='bold')
plt.xlabel('City', fontsize=11, fontweight='bold')
plt.ylabel('Jumlah Transaksi', fontsize=11, fontweight='bold')
max = TransaksiCity.max()
min = TransaksiCity.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = TransaksiCity.index
values = TransaksiCity.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# City
# London           922
# New York City    740
# Paris            537
# Los Angeles      510
# Toronto          431
# Tokyo            405
# Sydney           314
# Mexico City      193
# Seattle          170
# Aichi            162
# Name: Order ID, dtype: int64

# %%
Top10City = aws.groupby('City')['Profit'].sum().sort_values(ascending=False).head(10)
display(Top10City)

plt.figure(figsize=(14,6))
ax = sns.barplot(x=Top10City.index, y=Top10City.values, hue=Top10City.index, palette='muted')
plt.title('Total Profit berdasarkan City', fontsize=14, fontweight='bold')
plt.xlabel('City', fontsize=11, fontweight='bold')
plt.ylabel('Total Profit', fontsize=11, fontweight='bold')

max = Top10City.max()
min = Top10City.min()

ax.axhline(max, color='black', linestyle='--')
ax.axhline(min, color='red', linestyle='--')
categories = Top10City.index
values = Top10City.values.round(0)
for i in range(len(categories)):
    plt.text(i, values[i], str(values[i]), ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# City
# London           62218.6138
# New York City    30308.4886
# Toronto          29176.8289
# Los Angeles      17507.3854
# São Paulo        13939.3011
# Helsinki         11970.4817
# Luxembourg       10823.1874
# Mumbai           10375.9144
# Manila            8194.0833
# Dublin            7522.2916
# Name: Profit, dtype: float64

# %% [markdown]
# ## **Trash**
# ---

# %% [markdown]
# 1. Marketing Strategy (Discount, etc)
#
# - Pertanyaan 1: Bagaimana korelasi antara besaran diskon (Discount) dengan jumlah penjualan (Sales) dan akhirnya pengaruhnya terhadap profit?
# - Pertanyaan 2: Apakah produk-produk yang mendapatkan diskon lebih tinggi memiliki kecenderungan untuk dijual dalam jumlah besar atau kecil?
# - Pertanyaan 3: Bagaimana distribusi diskon di berbagai produk, dan apakah ada pola tertentu yang dapat diidentifikasi?
# - Pertanyaan 4: Apakah terdapat perbedaan performa penjualan antara produk yang mendapatkan diskon tinggi dengan produk yang tidak mendapatkan diskon?
#
# 2. Customer Segmentation
#
# - Pertanyaan 5: Apakah ada perbedaan signifikan dalam profit dari penjualan antara segmen pelanggan (SMB, Strategic, Enterprise, dll.)?
# - Pertanyaan 6: Bagaimana trend penjualan dan profit untuk setiap segmen pelanggan dari waktu ke waktu?
# - Pertanyaan 7: Apakah ada korelasi antara industri pelanggan dan profit yang dihasilkan dari penjualan?
#
# 3. Trendline Penjualan dari Waktu ke Waktu
#
# - Pertanyaan 8: Bagaimana tren penjualan keseluruhan SaaS dari waktu ke waktu, dan apakah terdapat musim atau pola tertentu?
# - Pertanyaan 9: Apakah terdapat produk tertentu yang memiliki kinerja penjualan lebih baik daripada yang lain selama periode tertentu?
#
# 4. Persebaran Geografis Penjualan (Region, Country, City)
#
# - Pertanyaan 10: Bagaimana profit penjualan SaaS terdistribusi di antara berbagai region (EMEA, AMER, APJ)?
# - Pertanyaan 11: Apakah ada perbedaan kinerja penjualan dan profit antara negara-negara atau kota-kota tertentu?
# - Pertanyaan 12: Apakah ada tren atau pola yang dapat diidentifikasi dalam persebaran geografis penjualan dari waktu ke waktu?
#
# `Prioritaskan Pertanyaan`
#
# -Prioritaskan pertanyaan berdasarkan kepentingan strategis dan potensi untuk meningkatkan profitabilitas. Misalnya, pertanyaan yang berkaitan dengan diskon (Marketing Strategy) dan customer segmentation dapat menjadi prioritas karena dapat memberikan wawasan langsung untuk meningkatkan strategi penjualan. Pertanyaan tentang trendline penjualan dan persebaran geografis dapat menjadi prioritas selanjutnya untuk memahami aspek-aspek jangka panjang dan lokasional penjualan.
